# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
usagers = pd.read_csv("Jeux_de_données/usagers-2019.csv", delimiter=";")
usagers
# Out:
#              Num_Acc  id_vehicule num_veh  place  catu  grav  sexe  an_nais  \
# 0       201900000001  138 306 524     B01      2     2     4     2     2002
# 1       201900000001  138 306 524     B01      1     1     4     2     1993
# 2       201900000001  138 306 525     A01      1     1     1     1     1959
# 3       201900000002  138 306 523     A01      1     1     4     2     1994
# 4       201900000003  138 306 520     A01      1     1     1     1     1996
# ...              ...          ...     ...    ...   ...   ...   ...      ...
# 132972  201900058837  137 982 135     C01      1     1     4     2     1988
# 132973  201900058838  137 982 132     A01      1     1     4     1     1998
# 132974  201900058839  137 982 131     A01      1     1     3     1     1979
# 132975  201900058840  137 982 129     B01      1     1     4     1     1974
# 132976  201900058840  137 982 130     A01      1     1     1     1     1971
#
#         trajet  secu1  secu2  secu3  locp actp  etatp
# ...

# %%
def clean_df(df):
    df.replace(-1, np.nan, inplace=True)
    df = df.replace(" -1", np.NAN)
    df = df.replace("0", np.NAN)
    df['trajet'] = df['trajet'].replace(0, np.NAN)
    df = df.rename(columns={'Num_Acc':'Num_Acc_id', 'place':'Place_Usager', 'catu':'Categorie_Usager', 'grav':'Gravblessure_Usager', 'sexe':'Sexe_Usager', 'an_nais':'Anne_Naissance_Usager', 'trajet':'Motif_Deplacer_Usager', 'secu1':'Equipement_Secu_Usager', 'locp':'Localisation_pieton_Usager', 'actp':'Action_pieton_Usager', 'etatp':'Nb_pieton_Usager'})
    df = df.drop(["num_veh", "secu2", "secu3"], axis=1)
    return df

# %%
df_cleanee = clean_df(usagers)

# %%
df_cleanee
# Out:
#           Num_Acc_id  id_vehicule  Place_Usager  Categorie_Usager  \
# 0       201900000001  138 306 524             2                 2
# 1       201900000001  138 306 524             1                 1
# 2       201900000001  138 306 525             1                 1
# 3       201900000002  138 306 523             1                 1
# 4       201900000003  138 306 520             1                 1
# ...              ...          ...           ...               ...
# 132972  201900058837  137 982 135             1                 1
# 132973  201900058838  137 982 132             1                 1
# 132974  201900058839  137 982 131             1                 1
# 132975  201900058840  137 982 129             1                 1
# 132976  201900058840  137 982 130             1                 1
#
#         Gravblessure_Usager  Sexe_Usager  Anne_Naissance_Usager  \
# 0                         4            2                   2002
# ...
